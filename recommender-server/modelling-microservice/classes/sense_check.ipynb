# %% [markdown]
# ### Trips ORM sense check
#
# The following notebook is used to sense check the trips ORM

# %%
from data_monolith import DataMonolith
from tips_model import TipsModel
from fare_model import FareModel
from congestion_model import CongestionModel

# %%
data = DataMonolith('localhost', 5432, 'haekim', 'password', 'taxis_and_ubers')
data.pull_date_range('2023-11-01', '2024-01-01')

# %%
tips_model = TipsModel(data.return_columns(['trip_distance', 'tip_amount']))
tips_model.clean()
tips_model.fit()
tips_model.plot_fit()
# Out:
# Fitting model...

# %%
fare = FareModel(data.return_columns(['trip_distance', 'fare_amount']))
fare.fit()
fare.plot_fit()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/research/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fare_amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 3
# ...
